# %% [markdown]
# #Dataset Description

# %% [markdown]
# \
#
# ## The dataset contains information about road traffic accidents with the following columns:
#
# `Time`: Time of the accident
#
# `Day_of_week`: Day of the week when the accident occurred
#
# `Age_band_of_driver`: Age group of the driver
#
# `Sex_of_driver`: Gender of the driver
#
# `Educational_level`: Educational level of the driver
#
# `Vehicle_driver_relation`: Relationship of the driver to the vehicle
#
# `Driving_experience`: Driving experience of the driver
#
# `Type_of_vehicle`: Type of vehicle involved in the accident
#
# `Owner_of_vehicle`: Owner of the vehicle
#
# `Service_year_of_vehicle`: Service years of the vehicle
#
# `Area_accident_occured`: Area where the accident occurred
#
# `Lanes_or_Medians`: Lanes or medians at the accident site
#
# `Road_allignment`: Road alignment at the accident site
#
# `Types_of_Junction`: Type of junction at the accident site
#
# `Road_surface_type`: Type of road surface at the accident site
#
# `Road_surface_conditions`: Road surface conditions at the accident site
#
# `Light_conditions`: Light conditions at the time of the accident
#
# `Weather_conditions`: Weather conditions at the time of the accident
#
# `Type_of_collision`: Type of collision
#
# `Number_of_vehicles_involved`: Number of vehicles involved in the accident
#
# `Number_of_casualties`: Number of casualties in the accident
#
# `Vehicle_movement`: Movement of the vehicle during the accident
#
# `Casualty_class`: Class of casualty (driver, passenger, pedestrian)
#
# `Sex_of_casualty`: Gender of the casualty
#
# `Age_band_of_casualty`: Age group of the casualty
#
# `Casualty_severity`: Severity of the casualty
#
# `Work_of_casuality`: Occupation of the casualty
#
# `Fitness_of_casuality`: Fitness of the casualty
#
# `Pedestrian_movement`: Movement of the pedestrian
#
# `Cause_of_accident`: Cause of the accident
#
# `Accident_severity`: Severity of the accident

# %% [markdown]
# # Tasks

# %% [markdown]
# ##1. Data Cleaning

# %% [markdown]
# ### Read the dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_csv('/content/drive/MyDrive/week1 exam/Task (1) Dataset.csv')
df.head(50)
# Out:
#         Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0   17:02:00      Monday              18-30          Male   Above high school
# 1   17:02:00      Monday              31-50          Male  Junior high school
# 2   17:02:00      Monday              18-30          Male  Junior high school
# 3    1:06:00      Sunday              18-30          Male  Junior high school
# 4    1:06:00      Sunday              18-30          Male  Junior high school
# 5   14:15:00      Friday              31-50          Male                 NaN
# 6   17:30:00   Wednesday              18-30          Male  Junior high school
# 7   17:20:00      Friday              18-30          Male  Junior high school
# 8   17:20:00      Friday              18-30          Male  Junior high school
# 9   17:20:00      Friday              18-30          Male  Junior high school
# 10  14:40:00    Saturday              18-30          Male   Above high school
# 11  14:40:00    Saturday              31-50          Male   Above high school
# 12  17:45:00    Thursday              18-30          Male  Junior high school
# 13  17:45:00    Thursday              31-50          Male  Junior high school
# 14  17:45:00    Thursday              31-50          Male  Junior high school
# 15  22:45:00      Monday              18-30        Female  Junior high school
# 16  22:45:00      Monday              18-30          Male  Junior high school
# 17  22:45:00      Monday              18-30          Male   Elementary school
# 18  22:45:00      Monday              18-30          Male  Junior high school
# 19   8:20:00     Tuesday              18-30          Male  Junior high school
# 20   8:20:00     Tuesday           Under 18          Male  Junior high school
# 21  15:10:00    Thursday              18-30          Male  Junior high school
# 22  12:11:00    Thursday              18-30          Male   Elementary school
# 23  12:11:00    Thursday              31-50          Male  Junior high school
# 24  18:36:00   Wednesday              18-30          Male                 NaN
# 25  18:36:00   Wednesday              18-30          Male  Junior high school
# 26  18:36:00   Wednesday              18-30       Unknown  Junior high school
# 27  14:35:00      Friday              18-30          Male   Above high school
# 28  12:25:00     Tuesday            Over 51       Unknown                 NaN
# 29  12:25:00     Tuesday              18-30          Male                 NaN
# 30  15:30:00      Monday              18-30          Male  Junior high school
# 31  18:10:00    Thursday              18-30          Male  Junior high school
# 32  15:25:00    Thursday              18-30          Male  Junior high school
# 33  15:25:00    Thursday              31-50       Unknown  Junior high school
# 34  13:57:00    Saturday            Over 51          Male  Junior high school
# 35  13:57:00    Saturday              18-30          Male         High school
# 36  20:30:00      Friday              18-30          Male   Above high school
# 37  20:30:00      Friday            Over 51          Male  Junior high school
# 38  20:30:00      Friday            Over 51          Male                 NaN
# 39  16:30:00      Sunday            Over 51          Male         High school
# 40  16:30:00      Sunday              31-50          Male         High school
# 41  21:50:00      Sunday              31-50          Male                 NaN
# 42  21:50:00      Sunday              18-30          Male         High school
# 43   9:12:00   Wednesday              18-30          Male  Junior high school
# 44   9:12:00   Wednesday              18-30          Male  Junior high school
# 45  14:40:00      Friday              31-50          Male  Junior high school
# 46  10:36:00      Friday              31-50          Male  Junior high school
# 47  10:36:00      Friday              31-50          Male             Unknown
# 48  18:19:00      Monday              18-30          Male  Junior high school
# 49  18:19:00      Monday              18-30          Male         High school
#
#    Vehicle_driver_relation Driving_experience       Type_of_vehicle  \
# 0                 Employee              1-2yr            Automobile
# 1                 Employee         Above 10yr   Public (> 45 seats)
# 2                 Employee              1-2yr       Lorry (41?100Q)
# 3                 Employee             5-10yr   Public (> 45 seats)
# 4                 Employee              2-5yr                   NaN
# 5                  Unknown                NaN                   NaN
# 6                 Employee              2-5yr            Automobile
# 7                 Employee              2-5yr            Automobile
# 8                 Employee         Above 10yr       Lorry (41?100Q)
# 9                 Employee              1-2yr            Automobile
# 10                   Owner              1-2yr  Public (13?45 seats)
# 11                Employee         No Licence            Automobile
# 12                Employee              1-2yr   Public (> 45 seats)
# 13                Employee             5-10yr       Lorry (41?100Q)
# 14                Employee         Above 10yr            Automobile
# 15                Employee         Above 10yr        Lorry (11?40Q)
# 16                   Owner             5-10yr  Public (13?45 seats)
# 17                Employee              2-5yr  Public (13?45 seats)
# 18                Employee              2-5yr                   NaN
# 19                Employee          Below 1yr            Long lorry
# 20                Employee              2-5yr       Lorry (41?100Q)
# 21                Employee              2-5yr        Lorry (11?40Q)
# 22                Employee             5-10yr       Lorry (41?100Q)
# 23                Employee         Above 10yr     Public (12 seats)
# 24                 Unknown                NaN                   NaN
# 25                Employee              2-5yr                  Taxi
# 26                Employee             5-10yr                   NaN
# 27                Employee              2-5yr            Automobile
# 28                 Unknown                NaN                   NaN
# 29                Employee              1-2yr       Lorry (41?100Q)
# 30                Employee              2-5yr            Automobile
# 31                Employee         Above 10yr            Automobile
# 32                Employee          Below 1yr       Lorry (41?100Q)
# 33                Employee              2-5yr            Automobile
# 34                Employee          Below 1yr            Automobile
# 35                Employee             5-10yr            Automobile
# 36                Employee              1-2yr                  Taxi
# 37                Employee          Below 1yr                   NaN
# 38                 Unknown                NaN                   NaN
# 39                Employee          Below 1yr            Automobile
# 40                Employee          Below 1yr      Pick up upto 10Q
# 41                 Unknown                NaN                   NaN
# 42                Employee              2-5yr            Automobile
# 43                Employee         Above 10yr     Public (12 seats)
# 44                Employee         Above 10yr  Public (13?45 seats)
# 45                Employee             5-10yr        Lorry (11?40Q)
# 46                Employee              1-2yr          Stationwagen
# 47                Employee          Below 1yr          Ridden horse
# 48                Employee          Below 1yr          Stationwagen
# 49                Employee              2-5yr            Automobile
#
#    Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# 0             Owner              Above 10yr  ...   Going straight
# 1             Owner                 5-10yrs  ...   Going straight
# 2             Owner                     NaN  ...   Going straight
# 3      Governmental                     NaN  ...   Going straight
# 4             Owner                 5-10yrs  ...   Going straight
# 5               NaN                     NaN  ...           U-Turn
# 6             Owner                     NaN  ...  Moving Backward
# 7      Governmental              Above 10yr  ...           U-Turn
# 8             Owner                   1-2yr  ...   Going straight
# 9             Owner                  2-5yrs  ...           U-Turn
# 10            Owner                 Unknown  ...         Turnover
# 11            Owner                     NaN  ...   Going straight
# 12            Owner                  2-5yrs  ...   Going straight
# 13            Owner              Above 10yr  ...    Waiting to go
# 14            Owner                   1-2yr  ...   Going straight
# 15            Owner                     NaN  ...   Going straight
# 16            Owner                     NaN  ...   Going straight
# 17            Owner                     NaN  ...   Going straight
# 18            Owner              Above 10yr  ...  Moving Backward
# 19            Owner                 5-10yrs  ...   Going straight
# 20            Owner                     NaN  ...   Going straight
# 21            Owner                 5-10yrs  ...  Moving Backward
# 22            Owner                     NaN  ...      Getting off
# 23            Owner                     NaN  ...        Reversing
# 24              NaN                     NaN  ...         Turnover
# 25            Owner              Above 10yr  ...   Going straight
# 26            Owner                  2-5yrs  ...   Going straight
# 27            Owner                  2-5yrs  ...   Going straight
# 28              NaN                     NaN  ...   Going straight
# 29            Owner                     NaN  ...   Going straight
# 30            Owner                     NaN  ...   Going straight
# 31     Governmental               Below 1yr  ...  Moving Backward
# 32            Owner                 5-10yrs  ...        Reversing
# 33     Governmental                     NaN  ...         Turnover
# 34            Owner                   1-2yr  ...   Going straight
# 35            Owner                  2-5yrs  ...   Going straight
# 36            Owner                     NaN  ...   Going straight
# 37            Owner                  2-5yrs  ...   Going straight
# 38            Owner                     NaN  ...   Going straight
# 39            Owner                     NaN  ...   Going straight
# 40            Owner              Above 10yr  ...   Going straight
# 41            Owner                 5-10yrs  ...   Going straight
# 42            Owner                     NaN  ...   Going straight
# 43            Owner                 Unknown  ...   Going straight
# 44     Governmental                     NaN  ...   Going straight
# 45            Owner                  2-5yrs  ...   Going straight
# 46            Owner                  2-5yrs  ...   Going straight
# 47            Owner                 Unknown  ...   Going straight
# 48            Owner                     NaN  ...   Going straight
# 49            Owner               Below 1yr  ...   Going straight
#
#      Casualty_class Sex_of_casualty Age_band_of_casualty Casualty_severity  \
# 0                na              na                   na                na
# 1                na              na                   na                na
# 2   Driver or rider            Male                31-50                 3
# 3        Pedestrian          Female                18-30                 3
# 4                na              na                   na                na
# 5   Driver or rider            Male                31-50                 3
# 6   Driver or rider          Female                18-30                 3
# 7                na              na                   na                na
# 8        Pedestrian            Male             Under 18                 3
# 9         Passenger            Male                18-30                 3
# 10               na              na                   na                na
# 11  Driver or rider            Male                18-30                 3
# 12               na              na                   na                na
# 13               na              na                   na                na
# 14  Driver or rider          Female                18-30                 3
# 15               na              na                   na                na
# 16               na              na                   na                na
# 17               na              na                   na                na
# 18               na              na                   na                na
# 19  Driver or rider            Male             Under 18                 3
# 20               na              na                   na                na
# 21  Driver or rider            Male                18-30                 3
# 22        Passenger          Female                31-50                 3
# 23        Passenger            Male                18-30                 3
# 24               na              na                   na                na
# 25  Driver or rider          Female                31-50                 3
# 26       Pedestrian            Male             Under 18                 3
# 27               na              na                   na                na
# 28  Driver or rider            Male                31-50                 3
# 29  Driver or rider            Male                18-30                 2
# 30               na              na                   na                na
# 31  Driver or rider            Male                18-30                 3
# 32        Passenger          Female                18-30                 3
# 33               na              na                   na                na
# 34  Driver or rider          Female                18-30                 3
# 35       Pedestrian            Male             Under 18                 3
# 36               na              na                   na                na
# 37  Driver or rider          Female                18-30                 2
# 38               na              na                   na                na
# 39  Driver or rider          Female                18-30                 3
# 40               na              na                   na                na
# 41  Driver or rider          Female                31-50                 3
# 42  Driver or rider            Male                18-30                 3
# 43       Pedestrian            Male             Under 18                 3
# 44  Driver or rider            Male             Under 18                 3
# 45               na              na                   na                na
# 46               na              na                   na                na
# 47  Driver or rider          Female                18-30                 3
# 48               na              na                   na                na
# 49  Driver or rider            Male                18-30                 2
#
#    Work_of_casuality Fitness_of_casuality  \
# 0                NaN                  NaN
# 1                NaN                  NaN
# 2             Driver                  NaN
# 3             Driver               Normal
# 4                NaN                  NaN
# 5             Driver               Normal
# 6             Driver               Normal
# 7                NaN               Normal
# 8             Driver               Normal
# 9             Driver               Normal
# 10               NaN               Normal
# 11            Driver               Normal
# 12            Driver               Normal
# 13             Other               Normal
# 14            Driver               Normal
# 15               NaN                  NaN
# 16            Driver               Normal
# 17            Driver               Normal
# 18        Unemployed               Normal
# 19            Driver               Normal
# 20            Driver               Normal
# 21            Driver               Normal
# 22            Driver               Normal
# 23          Employee               Normal
# 24            Driver               Normal
# 25     Self-employed               Normal
# 26            Driver               Normal
# 27            Driver               Normal
# 28               NaN                  NaN
# 29            Driver               Normal
# 30               NaN                  NaN
# 31            Driver                  NaN
# 32               NaN               Normal
# 33            Driver               Normal
# 34            Driver               Normal
# 35            Driver               Normal
# 36            Driver               Normal
# 37            Driver               Normal
# 38            Driver               Normal
# 39          Employee               Normal
# 40               NaN               Normal
# 41            Driver               Normal
# 42               NaN                  NaN
# 43     Self-employed               Normal
# 44               NaN                  NaN
# 45     Self-employed               Normal
# 46               NaN                  NaN
# 47     Self-employed               Normal
# 48               NaN                  NaN
# 49               NaN                  NaN
#
#                                   Pedestrian_movement  \
# 0                                    Not a Pedestrian
# 1                                    Not a Pedestrian
# 2                                    Not a Pedestrian
# 3                                    Not a Pedestrian
# 4                                    Not a Pedestrian
# 5                                    Not a Pedestrian
# 6                                    Not a Pedestrian
# 7                                    Not a Pedestrian
# 8                     Crossing from driver's nearside
# 9                                    Not a Pedestrian
# 10                                   Not a Pedestrian
# 11                                   Not a Pedestrian
# 12                                   Not a Pedestrian
# 13                                   Not a Pedestrian
# 14                                   Not a Pedestrian
# 15                                   Not a Pedestrian
# 16                                   Not a Pedestrian
# 17                                   Not a Pedestrian
# 18                                   Not a Pedestrian
# 19                                   Not a Pedestrian
# 20                                   Not a Pedestrian
# 21                                   Not a Pedestrian
# 22                                   Not a Pedestrian
# 23                                   Not a Pedestrian
# 24                                   Not a Pedestrian
# 25                                   Not a Pedestrian
# 26  Crossing from nearside - masked by parked or s...
# 27                                   Not a Pedestrian
# 28                                   Not a Pedestrian
# 29                                   Not a Pedestrian
# 30                                   Not a Pedestrian
# 31                                   Not a Pedestrian
# 32                                   Not a Pedestrian
# 33                                   Not a Pedestrian
# 34                                   Not a Pedestrian
# 35                                   Unknown or other
# 36                                   Not a Pedestrian
# 37                                   Not a Pedestrian
# 38                                   Not a Pedestrian
# 39                                   Not a Pedestrian
# 40                                   Not a Pedestrian
# 41                                   Not a Pedestrian
# 42                                   Not a Pedestrian
# 43  Crossing from nearside - masked by parked or s...
# 44                                   Not a Pedestrian
# 45                                   Not a Pedestrian
# 46                                   Not a Pedestrian
# 47                                   Not a Pedestrian
# 48                                   Not a Pedestrian
# 49                                   Not a Pedestrian
#
#                      Cause_of_accident Accident_severity
# 0                      Moving Backward     Slight Injury
# 1                           Overtaking     Slight Injury
# 2            Changing lane to the left    Serious Injury
# 3           Changing lane to the right     Slight Injury
# 4                           Overtaking     Slight Injury
# 5                          Overloading     Slight Injury
# 6                                Other     Slight Injury
# 7               No priority to vehicle     Slight Injury
# 8           Changing lane to the right     Slight Injury
# 9                      Moving Backward    Serious Injury
# 10           Changing lane to the left    Serious Injury
# 11           No priority to pedestrian    Serious Injury
# 12                       No distancing     Slight Injury
# 13              No priority to vehicle     Slight Injury
# 14                       No distancing    Serious Injury
# 15                       No distancing    Serious Injury
# 16                     Moving Backward     Slight Injury
# 17          Changing lane to the right    Serious Injury
# 18           No priority to pedestrian     Slight Injury
# 19                     Moving Backward    Serious Injury
# 20  Getting off the vehicle improperly     Slight Injury
# 21                          Overtaking    Serious Injury
# 22                         Overloading    Serious Injury
# 23          Changing lane to the right    Serious Injury
# 24                    Improper parking     Slight Injury
# 25                               Other     Slight Injury
# 26           Changing lane to the left     Slight Injury
# 27          Changing lane to the right     Slight Injury
# 28           No priority to pedestrian     Slight Injury
# 29                           Overspeed     Slight Injury
# 30           Changing lane to the left     Slight Injury
# 31              No priority to vehicle     Slight Injury
# 32          Changing lane to the right     Slight Injury
# 33                       No distancing     Slight Injury
# 34           No priority to pedestrian     Slight Injury
# 35                       No distancing     Slight Injury
# 36              No priority to vehicle     Slight Injury
# 37                               Other     Slight Injury
# 38                  Driving carelessly     Slight Injury
# 39           Changing lane to the left     Slight Injury
# 40                  Driving carelessly     Slight Injury
# 41           Changing lane to the left     Slight Injury
# 42              No priority to vehicle     Slight Injury
# 43                       No distancing     Slight Injury
# 44          Changing lane to the right     Slight Injury
# 45          Changing lane to the right    Serious Injury
# 46               Driving at high speed     Slight Injury
# 47                       No distancing     Slight Injury
# 48          Changing lane to the right     Slight Injury
# 49           Changing lane to the left     Slight Injury
#
# [50 rows x 32 columns]

# %%
df
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee              1-2yr
# 1      Junior high school                Employee         Above 10yr
# 2      Junior high school                Employee              1-2yr
# 3      Junior high school                Employee             5-10yr
# 4      Junior high school                Employee              2-5yr
# ...                   ...                     ...                ...
# 12311                 NaN                Employee              2-5yr
# 12312   Elementary school                Employee             5-10yr
# 12313  Junior high school                Employee             5-10yr
# 12314  Junior high school                Employee         Above 10yr
# 12315  Junior high school                Employee             5-10yr
#
#            Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 0               Automobile            Owner              Above 10yr  ...
# 1      Public (> 45 seats)            Owner                 5-10yrs  ...
# 2          Lorry (41?100Q)            Owner                     NaN  ...
# 3      Public (> 45 seats)     Governmental                     NaN  ...
# 4                      NaN            Owner                 5-10yrs  ...
# ...                    ...              ...                     ...  ...
# 12311       Lorry (11?40Q)            Owner                     NaN  ...
# 12312           Automobile            Owner                     NaN  ...
# 12313                Bajaj            Owner                  2-5yrs  ...
# 12314      Lorry (41?100Q)            Owner                  2-5yrs  ...
# 12315                Other            Owner                  2-5yrs  ...
#
#       Vehicle_movement   Casualty_class Sex_of_casualty Age_band_of_casualty  \
# 0       Going straight               na              na                   na
# 1       Going straight               na              na                   na
# 2       Going straight  Driver or rider            Male                31-50
# 3       Going straight       Pedestrian          Female                18-30
# 4       Going straight               na              na                   na
# ...                ...              ...             ...                  ...
# 12311   Going straight               na              na                   na
# 12312            Other               na              na                   na
# 12313            Other  Driver or rider            Male                31-50
# 12314            Other               na              na                   na
# 12315         Stopping       Pedestrian          Female                    5
#
#       Casualty_severity Work_of_casuality Fitness_of_casuality  \
# 0                    na               NaN                  NaN
# 1                    na               NaN                  NaN
# 2                     3            Driver                  NaN
# 3                     3            Driver               Normal
# 4                    na               NaN                  NaN
# ...                 ...               ...                  ...
# 12311                na            Driver               Normal
# 12312                na            Driver               Normal
# 12313                 3            Driver               Normal
# 12314                na            Driver               Normal
# 12315                 3            Driver               Normal
#
#                                      Pedestrian_movement  \
# 0                                       Not a Pedestrian
# 1                                       Not a Pedestrian
# 2                                       Not a Pedestrian
# 3                                       Not a Pedestrian
# 4                                       Not a Pedestrian
# ...                                                  ...
# 12311                                   Not a Pedestrian
# 12312                                   Not a Pedestrian
# 12313                                   Not a Pedestrian
# 12314                                   Not a Pedestrian
# 12315  Crossing from nearside - masked by parked or s...
#
#                           Cause_of_accident Accident_severity
# 0                           Moving Backward     Slight Injury
# 1                                Overtaking     Slight Injury
# 2                 Changing lane to the left    Serious Injury
# 3                Changing lane to the right     Slight Injury
# 4                                Overtaking     Slight Injury
# ...                                     ...               ...
# 12311                         No distancing     Slight Injury
# 12312                         No distancing     Slight Injury
# 12313            Changing lane to the right    Serious Injury
# 12314  Driving under the influence of drugs     Slight Injury
# 12315            Changing lane to the right     Slight Injury
#
# [12316 rows x 32 columns]

# %% [markdown]
# ### Handle Missing Values

# %%
df.isna().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# Casualty_severity                 0
# Work_of_casuality              3198
# Fitness_of_casuality           2635
# Pedestrian_movement               0
# Cause_of_accident                 0
# Accident_severity                 0
# dtype: int64

# %%
df.drop('Service_year_of_vehicle', axis=1, inplace=True)
df.drop('Defect_of_vehicle', axis=1, inplace=True)
df.drop('Work_of_casuality', axis=1, inplace=True)
df.drop('Fitness_of_casuality', axis=1, inplace=True)

df
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee              1-2yr
# 1      Junior high school                Employee         Above 10yr
# 2      Junior high school                Employee              1-2yr
# 3      Junior high school                Employee             5-10yr
# 4      Junior high school                Employee              2-5yr
# ...                   ...                     ...                ...
# 12311  Junior high school                Employee              2-5yr
# 12312   Elementary school                Employee             5-10yr
# 12313  Junior high school                Employee             5-10yr
# 12314  Junior high school                Employee         Above 10yr
# 12315  Junior high school                Employee             5-10yr
#
#            Type_of_vehicle Owner_of_vehicle Area_accident_occured  ...  \
# 0               Automobile            Owner     Residential areas  ...
# 1      Public (> 45 seats)            Owner          Office areas  ...
# 2          Lorry (41?100Q)            Owner    Recreational areas  ...
# 3      Public (> 45 seats)     Governmental          Office areas  ...
# 4               Automobile            Owner      Industrial areas  ...
# ...                    ...              ...                   ...  ...
# 12311       Lorry (11?40Q)            Owner   Outside rural areas  ...
# 12312           Automobile            Owner   Outside rural areas  ...
# 12313                Bajaj            Owner   Outside rural areas  ...
# 12314      Lorry (41?100Q)            Owner          Office areas  ...
# 12315                Other            Owner   Outside rural areas  ...
#
#       Number_of_vehicles_involved Number_of_casualties Vehicle_movement  \
# 0                               2                    2   Going straight
# 1                               2                    2   Going straight
# 2                               2                    2   Going straight
# 3                               2                    2   Going straight
# 4                               2                    2   Going straight
# ...                           ...                  ...              ...
# 12311                           2                    1   Going straight
# 12312                           2                    1            Other
# 12313                           1                    1            Other
# 12314                           2                    1            Other
# 12315                           2                    1         Stopping
#
#         Casualty_class Sex_of_casualty Age_band_of_casualty Casualty_severity  \
# 0                   na              na                   na                na
# 1                   na              na                   na                na
# 2      Driver or rider            Male                31-50                 3
# 3           Pedestrian          Female                18-30                 3
# 4                   na              na                   na                na
# ...                ...             ...                  ...               ...
# 12311               na              na                   na                na
# 12312               na              na                   na                na
# 12313  Driver or rider            Male                31-50                 3
# 12314               na              na                   na                na
# 12315       Pedestrian          Female                    5                 3
#
#                                      Pedestrian_movement  \
# 0                                       Not a Pedestrian
# 1                                       Not a Pedestrian
# 2                                       Not a Pedestrian
# 3                                       Not a Pedestrian
# 4                                       Not a Pedestrian
# ...                                                  ...
# 12311                                   Not a Pedestrian
# 12312                                   Not a Pedestrian
# 12313                                   Not a Pedestrian
# 12314                                   Not a Pedestrian
# 12315  Crossing from nearside - masked by parked or s...
#
#                           Cause_of_accident  Accident_severity
# 0                           Moving Backward      Slight Injury
# 1                                Overtaking      Slight Injury
# 2                 Changing lane to the left     Serious Injury
# 3                Changing lane to the right      Slight Injury
# 4                                Overtaking      Slight Injury
# ...                                     ...                ...
# 12311                         No distancing      Slight Injury
# 12312                         No distancing      Slight Injury
# 12313            Changing lane to the right     Serious Injury
# 12314  Driving under the influence of drugs      Slight Injury
# 12315            Changing lane to the right      Slight Injury
#
# [12316 rows x 28 columns]

# %%
df.isna().sum()
# Out:
# Time                             0
# Day_of_week                      0
# Age_band_of_driver               0
# Sex_of_driver                    0
# Educational_level                0
# Vehicle_driver_relation          0
# Driving_experience               0
# Type_of_vehicle                  0
# Owner_of_vehicle               482
# Area_accident_occured          239
# Lanes_or_Medians               385
# Road_allignment                142
# Types_of_Junction              887
# Road_surface_type              172
# Road_surface_conditions          0
# Light_conditions                 0
# Weather_conditions               0
# Type_of_collision              155
# Number_of_vehicles_involved      0
# Number_of_casualties             0
# Vehicle_movement               308
# Casualty_class                   0
# Sex_of_casualty                  0
# Age_band_of_casualty             0
# Casualty_severity                0
# Pedestrian_movement              0
# Cause_of_accident                0
# Accident_severity                0
# dtype: int64

# %%
df['Educational_level'].fillna(df['Educational_level'].mode()[0], inplace=True)
df['Vehicle_driver_relation'].fillna(df['Vehicle_driver_relation'].mode()[0], inplace=True)
df['Driving_experience'].fillna(df['Driving_experience'].mode()[0], inplace=True)
df['Owner_of_vehicle'].fillna(df['Owner_of_vehicle'].mode()[0], inplace=True)
df['Area_accident_occured'].fillna(df['Area_accident_occured'].mode()[0], inplace=True)
df['Type_of_collision'].fillna(df['Type_of_collision'].mode()[0], inplace=True)

# %%
df.isna().sum()
# Out:
# Time                             0
# Day_of_week                      0
# Age_band_of_driver               0
# Sex_of_driver                    0
# Educational_level                0
# Vehicle_driver_relation          0
# Driving_experience               0
# Type_of_vehicle                  0
# Owner_of_vehicle                 0
# Area_accident_occured            0
# Lanes_or_Medians               385
# Road_allignment                142
# Types_of_Junction              887
# Road_surface_type              172
# Road_surface_conditions          0
# Light_conditions                 0
# Weather_conditions               0
# Type_of_collision                0
# Number_of_vehicles_involved      0
# Number_of_casualties             0
# Vehicle_movement               308
# Casualty_class                   0
# Sex_of_casualty                  0
# Age_band_of_casualty             0
# Casualty_severity                0
# Pedestrian_movement              0
# Cause_of_accident                0
# Accident_severity                0
# dtype: int64

# %%
df['Lanes_or_Medians'].fillna(df['Lanes_or_Medians'].mode()[0], inplace=True)
df['Road_allignment'].fillna(df['Road_allignment'].mode()[0], inplace=True)
df['Types_of_Junction'].fillna(df['Types_of_Junction'].mode()[0], inplace=True)
df['Road_surface_type'].fillna(df['Road_surface_type'].mode()[0], inplace=True)
df['Vehicle_movement'].fillna(df['Vehicle_movement'].mode()[0], inplace=True)

# %% [markdown]
# ### Correct any inconsistent data entries.

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Ensure data types are appropriate for each column.
#
# ---
#
#
#
# ---

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 28 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            12316 non-null  object
#  5   Vehicle_driver_relation      12316 non-null  object
#  6   Driving_experience           12316 non-null  object
#  7   Type_of_vehicle              12316 non-null  object
#  8   Owner_of_vehicle             12316 non-null  object
#  9   Area_accident_occured        12316 non-null  object
#  10  Lanes_or_Medians             12316 non-null  object
#  11  Road_allignment              12316 non-null  object
#  12  Types_of_Junction            12316 non-null  object
#  13  Road_surface_type            12316 non-null  object
#  14  Road_surface_conditions      12316 non-null  object
#  15  Light_conditions             12316 non-null  object
#  16  Weather_conditions           12316 non-null  object
#  17  Type_of_collision            12316 non-null  object
#  18  Number_of_vehicles_involved  12316 non-null  int64
#  19  Number_of_casualties         12316 non-null  int64
#  20  Vehicle_movement             12316 non-null  object
#  21  Casualty_class               12316 non-null  object
#  22  Sex_of_casualty              12316 non-null  object
#  23  Age_band_of_casualty         12316 non-null  object
#  24  Casualty_severity            12316 non-null  object
#  25  Pedestrian_movement          12316 non-null  object
#  26  Cause_of_accident            12316 non-null  object
#  27  Accident_severity            12316 non-null  object
# dtypes: int64(2), object(26)
# memory usage: 2.6+ MB

# %%
Time=pd.to_datetime(Time,format='%y/%m/%d')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-715468c7c38f> in <cell line: 1>()
# ----> 1 Time=pd.to_datetime(Time,format='%y/%m/%d')
#
# NameError: name 'Time' is not defined

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
df.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                 12316.000000          12316.000000
# mean                      2.040679              1.548149
# std                       0.688790              1.007179
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000

# %%
df.nunique()
# Out:
# Time                           1074
# Day_of_week                       7
# Age_band_of_driver                5
# Sex_of_driver                     3
# Educational_level                 7
# Vehicle_driver_relation           4
# Driving_experience                7
# Type_of_vehicle                  17
# Owner_of_vehicle                  4
# Service_year_of_vehicle           6
# Defect_of_vehicle                 3
# Area_accident_occured            14
# Lanes_or_Medians                  7
# Road_allignment                   9
# Types_of_Junction                 8
# Road_surface_type                 5
# Road_surface_conditions           4
# Light_conditions                  4
# Weather_conditions                9
# Type_of_collision                10
# Number_of_vehicles_involved       6
# Number_of_casualties              8
# Vehicle_movement                 13
# Casualty_class                    4
# Sex_of_casualty                   3
# Age_band_of_casualty              6
# Casualty_severity                 4
# Work_of_casuality                 7
# Fitness_of_casuality              5
# Pedestrian_movement               9
# Cause_of_accident                20
# Accident_severity                 3
# dtype: int64

# %%
df.sort_values('Time', ascending=False).head()
# Out:
#           Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 5566   9:59:00     Tuesday            Over 51          Male
# 5567   9:59:00     Tuesday            Unknown          Male
# 9072   9:58:00    Saturday              31-50          Male
# 11966  9:57:00    Thursday            Over 51        Female
# 2178   9:57:00   Wednesday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 5566              Unknown                Employee         Above 10yr
# 5567    Elementary school                Employee             5-10yr
# 9072    Elementary school                   Other             5-10yr
# 11966   Above high school                Employee         No Licence
# 2178   Junior high school                Employee             5-10yr
#
#             Type_of_vehicle Owner_of_vehicle Area_accident_occured  ...  \
# 5566        Lorry (41?100Q)            Owner                 Other  ...
# 5567   Public (13?45 seats)            Owner                 Other  ...
# 9072        Lorry (41?100Q)            Owner                 Other  ...
# 11966          Stationwagen            Owner                 Other  ...
# 2178        Lorry (41?100Q)            Owner                 Other  ...
#
#       Number_of_vehicles_involved Number_of_casualties Vehicle_movement  \
# 5566                            2                    1  Moving Backward
# 5567                            2                    1   Going straight
# 9072                            1                    1            Other
# 11966                           1                    1         Turnover
# 2178                            2                    1            Other
#
#         Casualty_class Sex_of_casualty Age_band_of_casualty Casualty_severity  \
# 5566   Driver or rider            Male                18-30                 3
# 5567                na              na                   na                na
# 9072                na              na                   na                na
# 11966               na              na                   na                na
# 2178                na              na                   na                na
#
#       Pedestrian_movement          Cause_of_accident  Accident_severity
# 5566     Not a Pedestrian  No priority to pedestrian      Slight Injury
# 5567     Not a Pedestrian              No distancing      Slight Injury
# 9072     Not a Pedestrian     No priority to vehicle      Slight Injury
# 11966    Not a Pedestrian         Driving carelessly      Slight Injury
# 2178     Not a Pedestrian  No priority to pedestrian      Slight Injury
#
# [5 rows x 28 columns]

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
df.select_dtypes(include=['number']).corr()
# Out:
#                              Number_of_vehicles_involved  Number_of_casualties
# Number_of_vehicles_involved                     1.000000              0.213427
# Number_of_casualties                            0.213427              1.000000

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Age_band_of_driver, Type_of_vehicle).

# %%
plt.figure(figsize=(5, 2))
sns.histplot(df['Age_band_of_driver'], kde=True, color='red')
plt.title('Age_band_of_driver distribution')
# Out:
# Text(0.5, 1.0, 'Age_band_of_driver distribution')

# %%
plt.figure(figsize=(20, 10))
sns.histplot(df['Type_of_vehicle'], kde=True, color='red')
plt.title('Type_of_vehicle distribution')
# Out:
# Text(0.5, 1.0, 'Type_of_vehicle distribution')

# %% [markdown]
# ### Explore relationships between variables (e.g., Age_band_of_driver vs. Accident_severity).

# %%
import seaborn as sns

# %%
df.plot.scatter(x='Age_band_of_driver',y='Accident_severity')
# Out:
# <Axes: xlabel='Age_band_of_driver', ylabel='Accident_severity'>

# %% [markdown]
# ## 3. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), annot=True)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ## 4. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>

# %%
#the older the driver ,the lower the accident rate
#there is no clear relationship between Age ofdriver and Accident severity
